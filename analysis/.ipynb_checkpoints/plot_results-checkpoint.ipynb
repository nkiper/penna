# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
datadir = r'/Users/natasha/Desktop/projects/penna/analysis/data/2026-09-08_09-39-55_run

# %%
df = pd.read_csv('data/results.txt',delimiter=',', skiprows = 1)

# %%
df
# Out:
#       Iteration  Generation  Population number  Average age  \
# 0             0           0               1000       0.0000
# 1             0           1               1000       1.0000
# 2             0           2                981       2.0000
# 3             0           3                944       3.0000
# 4             0           4                904       4.0000
# ...         ...         ...                ...          ...
# 9995          0        9995                569      16.3005
# 9996          0        9996                579      16.1572
# 9997          0        9997                582      15.9656
# 9998          0        9998                591      16.0728
# 9999          0        9999                594      15.9663
#
#       Average no. of mutations  Average total mutations
# 0                      0.49200                  32.0000
# 1                      0.99900                  32.0000
# 2                      1.49337                  32.0000
# ...

# %%
df.keys()
# Out:
# Index(['Iteration', 'Generation', 'Population number', 'Average age',
#        'Average no. of mutations', 'Average total mutations'],
#       dtype='str')

# %%
plt.figure()
plt.plot(df['Generation'],df['Population number'])

# %%
plt.figure()
plt.plot(df['Generation'],df['Average no. of mutations'])

# %%
plt.figure()
plt.plot(df['Generation'],df['Average total mutations'])
